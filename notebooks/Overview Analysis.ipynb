# %%
import pandas as pd
import sys
import os
os.chdir('..')
sys.path.append(os.path.abspath('c:/Users/mama/Desktop/Week2/Telecom-bussiness-feasibility/src'))

# %%
# %run C:\Users\mama\Desktop\Week2\Telecom-bussiness-feasibility\notebooks\Cleaning_data.ipynb
# Out:
# c:\Users\mama\Desktop\Week2\Telecom-bussiness-feasibility\scripts\load_data.py:35: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, connection)
# Successfully loaded the data
# Your selected dataframe has 55 columns.
# There are 41 columns that have missing values.
# Missing Values in df:
#                                           Missing Values  % of Total Values  \
# Nb of sec with 37500B < Vol UL                    130254               86.8
# Nb of sec with 6250B < Vol UL < 37500B            111843               74.6
# Nb of sec with 125000B < Vol DL                    97538               65.0
# TCP UL Retrans. Vol (Bytes)                        96649               64.4
# Nb of sec with 31250B < Vol DL < 125000B           93586               62.4
# ...

# %%
print(Telecom_db)
# Out:
#            Bearer Id            Start  Start ms              End  End ms  \
# 0       1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1       1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2       1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 4       1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
# 6       1.311448e+19   4/13/2019 8:41     612.0   4/25/2019 8:16   168.0
# ...              ...              ...       ...              ...     ...
# 149994  1.311448e+19   4/29/2019 7:28      83.0  4/30/2019 15:01   268.0
# 149996  7.277826e+18   4/29/2019 7:28     451.0   4/30/2019 6:02   214.0
# 149997  7.349883e+18   4/29/2019 7:28     483.0  4/30/2019 10:41   187.0
# 149998  1.311448e+19   4/29/2019 7:28     283.0  4/30/2019 10:46   810.0
# 149999  1.311448e+19   4/29/2019 7:28     696.0  4/30/2019 10:40   327.0
#
#         Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# ...

# %%
from utils import get_top_n_handsets, get_top_n_manufacturers, get_top_handsets_per_manufacturer, calculate_xdr_sessions, calculate_session_duration, calculate_total_data, calculate_total_volume_per_application, calculate_total_data_volume_across_apps, correlation_analysis, plot_relationship, perform_regression_analysis, calculate_total_data_volume, plot_bivariate_analysis

# %%
top_handsets = get_top_n_handsets(Telecom_db, 'Handset Type', 10)
print(top_handsets)
# Out:
# Handset Type
# Huawei B528S-23A                19752
# Apple iPhone 6S (A1688)          9419
# Apple iPhone 6 (A1586)           9023
# Apple iPhone 7 (A1778)           6326
# Apple iPhone Se (A1723)          5187
# Apple iPhone 8 (A1905)           4993
# Apple iPhone Xr (A2105)          4568
# Samsung Galaxy S8 (Sm-G950F)     4520
# Apple iPhone X (A1901)           3813
# Samsung Galaxy A5 Sm-A520F       3724
# Name: count, dtype: int64

# %%
top_manufacturers = top_manufacturers = get_top_n_manufacturers(Telecom_db, 'Handset Manufacturer', 3)
print(top_manufacturers)
# Out:
# Handset Manufacturer
# Apple      59565
# Samsung    40839
# Huawei     34423
# Name: count, dtype: int64

# %%
top_handsets_by_manufacturer = get_top_handsets_per_manufacturer(Telecom_db, 'Handset Manufacturer', 'Handset Type', top_manufacturers, 5)
print(top_handsets_by_manufacturer)
# Out:
# {'Apple': Handset Type
# Apple iPhone 6S (A1688)    9419
# Apple iPhone 6 (A1586)     9023
# Apple iPhone 7 (A1778)     6326
# Apple iPhone Se (A1723)    5187
# Apple iPhone 8 (A1905)     4993
# Name: count, dtype: int64, 'Samsung': Handset Type
# Samsung Galaxy S8 (Sm-G950F)    4520
# Samsung Galaxy A5 Sm-A520F      3724
# Samsung Galaxy J5 (Sm-J530)     3696
# Samsung Galaxy J3 (Sm-J330)     3484
# Samsung Galaxy S7 (Sm-G930X)    3199
# Name: count, dtype: int64, 'Huawei': Handset Type
# Huawei B528S-23A                  19752
# Huawei E5180                       2079
# Huawei P20 Lite Huawei Nova 3E     2021
# Huawei P20                         1480
# Huawei Y6 2018                      997
# Name: count, dtype: int64}

# %%
# Assuming your DataFrame is named 'df'
session_id_column = 'Bearer Id'  
# Replace with the actual column name for session ID
xdr_sessions = calculate_xdr_sessions(Telecom_db, session_id_column)

# Display the number of XDR sessions
print(f"Number of XDR sessions: {xdr_sessions}")
# Out:
# Number of XDR sessions: 127098

# %%
start_time_column = 'Start'  # Replace with your actual start time column
end_time_column = 'End'  # Replace with your actual end time column
session_duration = calculate_session_duration(Telecom_db, start_time_column, end_time_column)

# Display total session duration in seconds
print(f"Total session duration (seconds): {session_duration.sum()}")
# Out:
# Total session duration (seconds): 14511153660.0
# c:\Users\mama\Desktop\Week2\Telecom-bussiness-feasibility\src\utils.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[start_time_column] = pd.to_datetime(df[start_time_column])
# c:\Users\mama\Desktop\Week2\Telecom-bussiness-feasibility\src\utils.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[end_time_column] = pd.to_datetime(df[end_time_column])
# ...

# %%
Telecom_db['Session_Duration_Hours'] = 14511153660 / 3600
# Out:
# C:\Users\mama\AppData\Local\Temp\ipykernel_10724\4289955778.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Telecom_db['Session_Duration_Hours'] = 14511153660 / 3600

# %%
dl_column = 'Total DL (Bytes)'  # Replace with your actual DL volume column
ul_column = 'Total UL (Bytes)'  # Replace with your actual UL volume column
total_dl, total_ul, total_data_volume = calculate_total_data(Telecom_db, dl_column, ul_column)

# Display the total download, upload, and data volume
print(f"Total Download (DL): {total_dl} Bytes")
print(f"Total Upload (UL): {total_ul} Bytes")
print(f"Total Data Volume: {total_data_volume} Bytes")
# Out:
# Total Download (DL): 63808390139383.0 Bytes
# Total Upload (UL): 5774781088862.0 Bytes
# Total Data Volume: 69583171228245.0 Bytes

# %%
# Define the list of applications
application = ['Social Media', 'Youtube', 'Netflix', 'Google', 'Gaming', 'Other', 'Email']

# Step 1: Calculate the total volume per row for each application
df = calculate_total_volume_per_application(Telecom_db, application)

# Display the updated DataFrame with total volumes for each application
print("Data with Total Volume per row:")
print(df)

# Step 2: Calculate the total data volume for each application across all rows
total_data_per_app = calculate_total_data_volume_across_apps(Telecom_db, application)

# Display the total data volume per application across all rows
print("\nTotal Data Volume per Application:")
print(total_data_per_app)
# Out:
# Data with Total Volume per row:
#            Bearer Id               Start  Start ms                 End  \
# 0       1.311448e+19 2019-04-04 12:01:00     770.0 2019-04-25 14:35:00
# 1       1.311448e+19 2019-04-09 13:04:00     235.0 2019-04-25 08:15:00
# 2       1.311448e+19 2019-04-09 17:42:00       1.0 2019-04-25 11:58:00
# 4       1.311448e+19 2019-04-12 20:10:00     565.0 2019-04-25 10:40:00
# 6       1.311448e+19 2019-04-13 08:41:00     612.0 2019-04-25 08:16:00
# ...              ...                 ...       ...                 ...
# 149994  1.311448e+19 2019-04-29 07:28:00      83.0 2019-04-30 15:01:00
# 149996  7.277826e+18 2019-04-29 07:28:00     451.0 2019-04-30 06:02:00
# 149997  7.349883e+18 2019-04-29 07:28:00     483.0 2019-04-30 10:41:00
# 149998  1.311448e+19 2019-04-29 07:28:00     283.0 2019-04-30 10:46:00
# 149999  1.311448e+19 2019-04-29 07:28:00     696.0 2019-04-30 10:40:00
#
#         End ms  Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# ...

# %%
# Define the list of applications
applications = ['Social Media', 'Youtube', 'Netflix', 'Google', 'Gaming', 'Other', 'Email']


# Step 1: Calculate Total Data Volume
Telecom = calculate_total_data_volume(Telecom_db, applications)

# Step 2: Correlation Analysis
correlation_results = correlation_analysis(Telecom_db, applications)
print("Correlation between each application and total data volume:")
print(correlation_results)

# Step 3: Plot the relationship between each application's data and total data volume
#plot_relationship(Telecom_db, applications)

# Step 4: Perform Regression Analysis
r2_results = perform_regression_analysis(df, applications)
print("\nR-squared values for regression analysis:")
print(r2_results)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 6
#       2 applications = ['Social Media', 'Youtube', 'Netflix', 'Google', 'Gaming', 'Other', 'Email']
#       5 # Step 1: Calculate Total Data Volume
# ----> 6 Telecom = calculate_total_data_volume(Telecom_db, applications)
#       8 # Step 2: Correlation Analysis
#       9 correlation_results = correlation_analysis(Telecom_db, applications)
#
# TypeError: calculate_total_data_volume() takes 1 positional argument but 2 were given
