# %%
import sys
import os
os.chdir('..')
sys.path.append(os.path.abspath('c:/Users/mama/Desktop/Week2/Telecom-bussiness-feasibility/scripts'))
sys.path.append(os.path.abspath('c:/Users/mama/Desktop/Week2/Telecom-bussiness-feasibility/src'))

# %%
from load_data import load_data_from_postgres

# %%
# Define your SQL query
query = "SELECT * FROM xdr_data;"  # Replace with your actual table name

# Load data from PostgreSQL
telecom = load_data_from_postgres(query)

# Display the first few rows of the dataframe
if telecom is not None:
    print("Successfully loaded the data")
else:
    print("Failed to load data.")
# Out:
# c:\Users\mama\Desktop\Week2\Telecom-bussiness-feasibility\scripts\load_data.py:35: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, connection)
# Successfully loaded the data

# %%
telecom.head()
# Out:
#       Bearer Id            Start  Start ms              End  End ms  \
# 0  1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1  1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2  1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3  1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4  1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
#
#    Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# 0  1823652.0  2.082014e+14   3.366496e+10  3.552121e+13
# 1  1365104.0  2.082019e+14   3.368185e+10  3.579401e+13
# 2  1361762.0  2.082003e+14   3.376063e+10  3.528151e+13
# 3  1321509.0  2.082014e+14   3.375034e+10  3.535661e+13
# 4  1089009.0  2.082014e+14   3.369980e+10  3.540701e+13
#
#       Last Location Name  ...  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# 0  9.16456699548519E+015  ...          15854611.0           2501332.0
# 1                L77566A  ...          20247395.0          19111729.0
# ...

# %%
from utils import missing_values_table, convert_bytes_to_megabytes, remove_rows_with_missing_values, fill_missing_values, check_undefined

# %%
missing_values_df = missing_values_table(telecom)
print("Missing Values in df:")
print(missing_values_df)
# Out:
# Your selected dataframe has 55 columns.
# There are 41 columns that have missing values.
# Missing Values in df:
#                                           Missing Values  % of Total Values  \
# Nb of sec with 37500B < Vol UL                    130254               86.8
# Nb of sec with 6250B < Vol UL < 37500B            111843               74.6
# Nb of sec with 125000B < Vol DL                    97538               65.0
# TCP UL Retrans. Vol (Bytes)                        96649               64.4
# Nb of sec with 31250B < Vol DL < 125000B           93586               62.4
# Nb of sec with 1250B < Vol UL < 6250B              92894               61.9
# Nb of sec with 6250B < Vol DL < 31250B             88317               58.9
# TCP DL Retrans. Vol (Bytes)                        88146               58.8
# HTTP UL (Bytes)                                    81810               54.5
# HTTP DL (Bytes)                                    81474               54.3
# ...

# %% [markdown]
# # Steps to clean data for Eda

# %%
columns_to_check = ['Handset Type', 'Handset Manufacturer', 'Start ms', 'End ms', 'Dur. (ms).1', 'Activity Duration UL (ms)', 'Total DL (Bytes)', 'Avg Bearer TP UL (kbps)','Activity Duration UL (ms)' ]

# Use the function to remove rows with missing values in the specified columns
Telecom_cleaned = remove_rows_with_missing_values(telecom, columns_to_check)

# Display the cleaned DataFrame
print("\nDataFrame after Removing Rows with Missing Values in 'Age' or 'Salary':")
print(Telecom_cleaned)
# Out:
# DataFrame after Removing Rows with Missing Values in 'Age' or 'Salary':
#            Bearer Id            Start  Start ms              End  End ms  \
# 0       1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1       1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2       1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3       1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4       1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
# ...              ...              ...       ...              ...     ...
# 149995  1.304243e+19   4/29/2019 7:28     615.0   4/30/2019 0:01   407.0
# 149996  7.277826e+18   4/29/2019 7:28     451.0   4/30/2019 6:02   214.0
# 149997  7.349883e+18   4/29/2019 7:28     483.0  4/30/2019 10:41   187.0
# 149998  1.311448e+19   4/29/2019 7:28     283.0  4/30/2019 10:46   810.0
# 149999  1.311448e+19   4/29/2019 7:28     696.0  4/30/2019 10:40   327.0
#
# ...

# %%
filling_methods = {

    'Nb of sec with 37500B < Vol UL': 'median',
    'Nb of sec with 6250B < Vol UL < 37500B': 'median',
    'Nb of sec with 125000B < Vol DL': 'median',
    'TCP UL Retrans. Vol (Bytes)': 'median',
    'Nb of sec with 31250B < Vol DL < 125000B': 'median',
    'Nb of sec with 1250B < Vol UL < 6250B': 'median',
    'Nb of sec with 6250B < Vol DL < 31250B': 'median',
    'TCP DL Retrans. Vol (Bytes)': 'median',
    'HTTP UL (Bytes)': 'median',
    'HTTP DL (Bytes)': 'median',
    'Avg RTT DL (ms)': 'median',
    'Avg RTT UL (ms)': 'median',
    'Last Location Name': 'mode',
    'IMEI': 'mode',
    'IMSI': 'mode',
    'Bearer Id': 'mode',

    'MSISDN/Number': 'knn',
    'Start': 'interpolation',
    
    

    'Nb of sec with Vol UL < 1250B': 'mean',
    '10 Kbps < UL TP < 50 Kbps (%)': 'mean',
    'UL TP > 300 Kbps (%)': 'mean',
    '50 Kbps < UL TP < 300 Kbps (%)': 'mean',
    'UL TP < 10 Kbps (%)': 'mean',
    'Nb of sec with Vol DL < 6250B': 'mean',
    '250 Kbps < DL TP < 1 Mbps (%)': 'mean',
    '50 Kbps < DL TP < 250 Kbps (%)': 'mean',
    'DL TP < 50 Kbps (%)': 'mean',
    'DL TP > 1 Mbps (%)': 'mean',
    'Total UL (Bytes)': 'mean'
     


 

        # Adding multiple columns for median imputation
}

# Apply the fill_missing_values function using the selected methods
Telecom_filled = fill_missing_values(Telecom_cleaned, filling_methods)

# Display the DataFrame after filling missing values
print("\nDataFrame after Filling Missing Values with Median:")
print(Telecom_filled)
# Out:
# c:\Users\mama\Desktop\Week2\Telecom-bussiness-feasibility\src\utils.py:115: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(df[column].median(), inplace=True)
# c:\Users\mama\Desktop\Week2\Telecom-bussiness-feasibility\src\utils.py:115: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %% [markdown]
# Checking any Missing value left

# %%
missing_values_df = missing_values_table(Telecom_filled)
print("Missing Values in df:")
print(missing_values_df)
# Out:
# Your selected dataframe has 55 columns.
# There are 0 columns that have missing values.
# Missing Values in df:
# Empty DataFrame
# Columns: [Missing Values, % of Total Values, Dtype]
# Index: []

# %%
# Check for undefined values in the DataFrame
undefined_columns = check_undefined(Telecom_filled)
print("Columns with 'undefined' values and their counts:", undefined_columns)
# Out:
# Columns with 'undefined' values and their counts: {'Handset Manufacturer': np.int64(8987), 'Handset Type': np.int64(8987)}

# %%
import numpy as np

# %%
Telecom_filled.replace('undefined', np.nan, inplace=True)
# Out:
# C:\Users\mama\AppData\Local\Temp\ipykernel_2944\269809415.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Telecom_filled.replace('undefined', np.nan, inplace=True)

# %%
# Drop rows that contain NaN values
Telecom_db = Telecom_filled.dropna()

# Display the cleaned DataFrame
print("Data after dropping rows with 'undefined' values:")
print(Telecom_db)
# Out:
# Data after dropping rows with 'undefined' values:
#            Bearer Id            Start  Start ms              End  End ms  \
# 0       1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1       1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2       1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 4       1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
# 6       1.311448e+19   4/13/2019 8:41     612.0   4/25/2019 8:16   168.0
# ...              ...              ...       ...              ...     ...
# 149994  1.311448e+19   4/29/2019 7:28      83.0  4/30/2019 15:01   268.0
# 149996  7.277826e+18   4/29/2019 7:28     451.0   4/30/2019 6:02   214.0
# 149997  7.349883e+18   4/29/2019 7:28     483.0  4/30/2019 10:41   187.0
# 149998  1.311448e+19   4/29/2019 7:28     283.0  4/30/2019 10:46   810.0
# 149999  1.311448e+19   4/29/2019 7:28     696.0  4/30/2019 10:40   327.0
#
# ...

# %% [markdown]
# Now My xdr data is clean.
